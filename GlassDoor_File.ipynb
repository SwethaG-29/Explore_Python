# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_rows",None)

# %%
file = pd.read_csv("/Users/swethag/Desktop/@Upgrad_Data_Science/Python Docs/Self Study From Upgrad/Course 5/Advanced DataBase Programming using Pandas/v1.2.csv")
file.head(4)
# Out:
#                                 Unnamed: 0                Unnamed: 1  \
# 0                                      NaN                       NaN
# 1                                      NaN                       NaN
# 2                              Competitors                   Revenue
# 3  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
#
#   GLASSDOOR JOBS          Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# 0            NaN                 NaN                     NaN        NaN
# 1            NaN                 NaN                     NaN        NaN
# 2         Sector            Industry          Ownership Type    Founded
# 3      Insurance  Insurance Carriers  Nonprofit Organization       1993
#
#                Unnamed: 6    Unnamed: 7    Unnamed: 8        Unnamed: 9  \
# 0                     NaN           NaN           NaN               NaN
# 1                     NaN           NaN           NaN               NaN
# ...

# %%
### Removing 3 rows and making 2nd row as index using header = 2

df = pd.read_csv("/Users/swethag/Desktop/@Upgrad_Data_Science/Python Docs/Self Study From Upgrad/Course 5/Advanced DataBase Programming using Pandas/v1.2.csv",header = 3)
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
# dropping index column as it ti not required 
df.drop("index",axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
### Checking Value_counts() for all columns

for i in df.columns:
    print(i,":-",df[i].value_counts(),"\n","-"*50)
# Out:
# Competitors :- Competitors
# -1                                                                                              512
# Roche, GlaxoSmithKline, Novartis                                                                 10
# Los Alamos National Laboratory, Battelle, SRI International                                       6
# Leidos, CACI International, Booz Allen Hamilton                                                   6
# IMAGE Skincare, Aveda, Kiehl's                                                                    4
#                                                                                                ...
# Los Alamos National Laboratory, NASA Jet Propulsion Laboratory, Sandia National Laboratories      1
# Fluor, Bechtel, AECOM                                                                             1
# Intertek, SGS, Bureau Veritas                                                                     1
# ...

# %%
df.columns
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title'],
#       dtype='object')

# %%
l1 = "C_" + df.columns[0:11] ### Company
l1
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating'],
#       dtype='object')

# %%
l2 = "J_" + df.columns[11:14] ### Job 
l2
# Out:
# Index(['J_Description', 'J_Salary', 'J_Title'], dtype='object')

# %%
new_list= l1.append(l2)
new_list
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
df.columns = new_list

# %%
df.columns
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
df2 = df.copy()
df2.head(2)
# Out:
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
#              C_Name C_Rating  \
# 0  Healthfirst\n3.1      3.1
# 1      ManTech\n4.2      4.2
#
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title
# ...

# %%
df2 = df2.add_prefix("GlassDoor_")
df2.head(2)
# Out:
#                    GlassDoor_C_Competitors       GlassDoor_C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#   GlassDoor_C_Sector    GlassDoor_C_Industry GlassDoor_C_Ownership Type  \
# 0          Insurance      Insurance Carriers     Nonprofit Organization
# 1  Business Services  Research & Development           Company - Public
#
#    GlassDoor_C_Founded         GlassDoor_C_Size GlassDoor_C_Headquarters  \
# 0                 1993   1001 to 5000 employees             New York, NY
# 1                 1968  5001 to 10000 employees              Herndon, VA
#
#   GlassDoor_C_Location  GlassDoor_C_Name GlassDoor_C_Rating  \
# 0         New York, NY  Healthfirst\n3.1                3.1
# 1        Chantilly, VA      ManTech\n4.2                4.2
#
#                              GlassDoor_J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# ...

# %% [markdown]
# ### Re-Ordering the columns

# %%
###Solution 1

list(df.columns[11:]) + list(df.columns[:11])
# Out:
# ['J_Description',
#  'J_Salary',
#  'J_Title',
#  'C_Competitors',
#  'C_Revenue',
#  'C_Sector',
#  'C_Industry',
#  'C_Ownership Type',
#  'C_Founded',
#  'C_Size',
#  'C_Headquarters',
#  'C_Location',
#  'C_Name',
#  'C_Rating']

# %%
df = df[list(df.columns[11:]) + list(df.columns[:11])]
df.head(2)
# Out:
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title  \
# 0  $137K-$171K (Glassdoor est.)  Sr Data Scientist
# 1  $137K-$171K (Glassdoor est.)     Data Scientist
#
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
# ...

# %%
### Solution 2

df = df.loc[:, ::-1]
df.head(2)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...      3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...      4.2
#
#              C_Name     C_Location C_Headquarters                   C_Size  \
# 0  Healthfirst\n3.1   New York, NY   New York, NY   1001 to 5000 employees
# 1      ManTech\n4.2  Chantilly, VA    Herndon, VA  5001 to 10000 employees
#
#    C_Founded        C_Ownership Type              C_Industry  \
# 0       1993  Nonprofit Organization      Insurance Carriers
# 1       1968        Company - Public  Research & Development
#
#             C_Sector                 C_Revenue  \
# 0          Insurance  Unknown / Non-Applicable
# 1  Business Services    $1 to $2 billion (USD)
#
#                              C_Competitors
# ...

# %% [markdown]
# ### DataType Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Description     689 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Title           684 non-null    object
#  3   C_Competitors     689 non-null    object
#  4   C_Revenue         689 non-null    object
#  5   C_Sector          689 non-null    object
#  6   C_Industry        689 non-null    object
#  7   C_Ownership Type  689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Size            689 non-null    object
#  10  C_Headquarters    689 non-null    object
#  11  C_Location        689 non-null    object
#  12  C_Name            689 non-null    object
#  13  C_Rating          684 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %%
df.C_Rating.value_counts()
# Out:
# C_Rating
# 3.5      61
# -1       50
# 3.3      42
# 3.8      40
# 4        40
# 3.9      40
# 3.7      40
# 5        36
# 4.5      34
# 3.6      31
# 3.4      31
# 4.2      29
# 4.1      26
# 3.2      22
# 4.4      22
# 4.7      21
# 4.8      20
# 4.3      13
# 2.9      13
# 4.6      12
# 3.1      12
# 4.9      11
# 2.7      10
# 3         7
# 2.6       4
# 2.8       3
# 2.5       3
# 2*+.9     1
# 2.1       1
# 2.3       1
# 5.2       1
# 2.4       1
# 3.8*/     1
# /3.7      1
# 2.2       1
# 5.6       1
# 4.4*      1
# 2         1
# Name: count, dtype: int64

# %%
### Checking missing values
df.isnull().mean()*100
# Out:
# C_Rating            0.725689
# C_Name              0.000000
# C_Location          0.000000
# C_Headquarters      0.000000
# C_Size              0.000000
# C_Founded           0.000000
# C_Ownership Type    0.000000
# C_Industry          0.000000
# C_Sector            0.000000
# C_Revenue           0.000000
# C_Competitors       0.000000
# J_Title             0.725689
# J_Salary            0.000000
# J_Description       0.000000
# dtype: float64

# %%
df[df["C_Rating"].isna()]
# Out:
#     C_Rating                                     C_Name       C_Location  \
# 49       NaN                            Quick Base\n4.3    Cambridge, MA
# 67       NaN                         Grid Dynamics\n4.0  Santa Clara, CA
# 157      NaN  Guzman & Griffin Technologies (GGTI)\n4.4   Washington, DC
# 350      NaN                    Praxis Engineering\n4.7    Chantilly, VA
# 686      NaN                         Grid Dynamics\n4.0  Santa Clara, CA
#
#              C_Headquarters                  C_Size  C_Founded  \
# 49            Cambridge, MA    201 to 500 employees       1999
# 67            San Ramon, CA  1001 to 5000 employees       2006
# 157        Mays Landing, NJ       1 to 50 employees       1997
# 350  Annapolis Junction, MD    201 to 500 employees       2002
# 686           San Ramon, CA  1001 to 5000 employees       2006
#
#                    C_Ownership Type                               C_Industry  \
# ...

# %%
### Replacing the "na" values

df[df.C_Rating.isna()].shape
# Out:
# (5, 14)

# %%
### Storing the index value in a var

index_C_Rating = df[df.C_Rating.isna()].index
index_C_Rating
# Out:
# Index([49, 67, 157, 350, 686], dtype='int64')

# %%
len(index_C_Rating)
# Out:
# 5

# %%
ls = []
for i in range(0, len(index_C_Rating)):
    ls.append(df.iloc[index_C_Rating[i]]['C_Name'].split('\n')[1])

# %%
ls
# Out:
# ['4.3', '4.0', '4.4', '4.7', '4.0']

# %%
df.iloc[index_C_Rating,3] = ls

# %%
### NULL values is replaced 
df.iloc[index_C_Rating]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      4.3
# 67   As a member of the Data Science team, this rol...      4.0
# 157  *******Please Apply using this link: https://a...      4.4
# 350  What will you be doing?\n\nThe Contractor shal...      4.7
# 686  As a member of the Data Science team, this rol...      4.0
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
### Getting the wrong values and storing it in list

for i in (df[~df.C_Rating.isna()] ["C_Rating"]):
    if len(i) > 3:
        print(i)
# Out:
# 4.4*
# /3.7
# 3.8*/
# 2*+.9

# %%
l = []

for i in df["C_Rating"]:
    try:
        pd.to_numeric(i)
    except ValueError:
        l.append(i)
print("Erronous list are",l)
# Out:
# Erronous list are ['4.4*', '/3.7', '3.8*/', '2*+.9']

# %%
df.C_Rating
# Out:
# 0      3.1
# 1      4.2
# 2      3.8
# 3      3.5
# 4      2.9
#       ...
# 684    3.7
# 685    3.7
# 686    NaN
# 687    3.3
# 688    2.5
# Name: C_Rating, Length: 689, dtype: object

# %%
df.iloc[index_C_Rating]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      4.3
# 67   As a member of the Data Science team, this rol...      4.0
# 157  *******Please Apply using this link: https://a...      4.4
# 350  What will you be doing?\n\nThe Contractor shal...      4.7
# 686  As a member of the Data Science team, this rol...      4.0
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
df.C_Rating.isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          689 non-null    object
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %%
### Chaning the datatype of "C_Rating" column
def cleaner(str):
    cleaner_str = "".join(filter(lambda x: (x in "0123456789."),str))
    return float(cleaner_str)

# %%
df.C_Rating = df["C_Rating"].apply(cleaner)

# %%
df['C_Rating'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# __Cleaning the Name column__

# %%
df[['C_Name', 'Delete']] = df['C_Name'].str.split('\n', expand=True)

df.drop("Delete", axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating       C_Name  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1  Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2      ManTech
#
#       C_Location C_Headquarters                   C_Size  C_Founded  \
# 0   New York, NY   New York, NY   1001 to 5000 employees       1993
# 1  Chantilly, VA    Herndon, VA  5001 to 10000 employees       1968
#
#          C_Ownership Type              C_Industry           C_Sector  \
# 0  Nonprofit Organization      Insurance Carriers          Insurance
# 1        Company - Public  Research & Development  Business Services
#
#                   C_Revenue                            C_Competitors
# 0  Unknown / Non-Applicable  EmblemHealth, UnitedHealth Group, Aetna
# ...

# %% [markdown]
# __Cleaning the Title Column__

# %%
df.J_Title.value_counts()
# Out:
# J_Title
# Data Scientist                                                                                      337
# Data Engineer                                                                                        27
# Senior Data Scientist                                                                                20
# Machine Learning Engineer                                                                            17
# Data Analyst                                                                                         13
# Senior Data Analyst                                                                                   6
# Senior Data Engineer                                                                                  5
# Data Science Software Engineer                                                                        4
# Data Scientist - TS/SCI FSP or CI Required                                                            4
# ...

# %%
df.J_Title.isna().sum()
# Out:
# 5

# %%
df[df.J_Title.isna()]
# Out:
#     J_Title                      J_Salary  \
# 4       NaN  $137K-$171K (Glassdoor est.)
# 9       NaN  $137K-$171K (Glassdoor est.)
# 38      NaN   $75K-$131K (Glassdoor est.)
# 290     NaN  $141K-$225K (Glassdoor est.)
# 396     NaN  $110K-$163K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 4    Data Scientist\nAffinity Solutions / Marketing...       2.9
# 9    Ready to write the best chapter of your career...       3.6
# 38   Job Title: Data Scientists\n\nJob Description\...       2.2
# 290  Work Authorization Those authorized to work in...       1.0
# 396  Meridian Knowledge Solutions, LLC, is the lead...       4.3
#
#                                   C_Name         C_Location C_Headquarters  \
# 4                     Affinity Solutions       New York, NY   New York, NY
# 9                     XSELL Technologies        Chicago, IL    Chicago, IL
# 38             Great-Circle Technologies      Chantilly, VA  Chantilly, VA
# ...

# %%
title_mode = df.J_Title.mode()
title_mode
# Out:
# 0    Data Scientist
# Name: J_Title, dtype: object

# %%
df.J_Title = df.J_Title.fillna("title_mode")

# %%
df.J_Title.isnull().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4         title_mode  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %% [markdown]
# ##### Locating Erroneous Value

# %%
df.eq('-1').sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded             0
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
(df.eq(-1) + df.eq("-1")).sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
cols = df.columns
cols
# Out:
# Index(['J_Title', 'J_Salary', 'J_Description', 'C_Rating', 'C_Name',
#        'C_Location', 'C_Headquarters', 'C_Size', 'C_Founded',
#        'C_Ownership Type', 'C_Industry', 'C_Sector', 'C_Revenue',
#        'C_Competitors'],
#       dtype='object')

# %%
for i in cols:
    df.loc[df[i].isin([-1,'-1'])] = np.NaN

# %%
df.isna().sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64
