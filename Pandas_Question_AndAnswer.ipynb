# %%
import pandas as pd
import numpy as np

# %%
new_sales  = pd.read_csv('/Users/swethag/Desktop/@Upgrad_Data_Science/Practice exam/MegaMart_newsales.csv')
sales = pd.read_csv('/Users/swethag/Desktop/@Upgrad_Data_Science/Practice exam/MegaMart_sales.csv')

# %%
new_sales.head()
# Out:
#           Order ID                         Product Name  Discount  Sales  \
# 0  AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
# 1  AZ-2011-1916360        Dania 3-Shelf Cabinet, Mobile       0.0    288
# 2  AZ-2011-1916555          Eldon Folders, Single Width       0.4     61
# 3  AZ-2011-1930058          Sanford Markers, Easy-Erase       0.0     71
# 4  AZ-2011-1967754         Logitech Numeric Keypad, USB       0.0     93
#
#    Profit  Quantity         Category Sub-Category
# 0     102         7  Office Supplies      Binders
# 1      20         2        Furniture    Bookcases
# 2       7         6  Office Supplies      Storage
# 3       1         3  Office Supplies          Art
# 4      40         2       Technology  Accessories

# %% [markdown]
# Combining data frames
# Read the .csv files MegaMart_sales and MegaMart_new sales into two separate dataframes, combine them and store it into a new dataframe. Find the total sales value of the category 'Office Supplies'  after combining the dataframes.

# %%
df = pd.concat([new_sales,sales], axis = 0, ignore_index = False)

# %%
df.head()
# Out:
#           Order ID                         Product Name  Discount  Sales  \
# 0  AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
# 1  AZ-2011-1916360        Dania 3-Shelf Cabinet, Mobile       0.0    288
# 2  AZ-2011-1916555          Eldon Folders, Single Width       0.4     61
# 3  AZ-2011-1930058          Sanford Markers, Easy-Erase       0.0     71
# 4  AZ-2011-1967754         Logitech Numeric Keypad, USB       0.0     93
#
#    Profit  Quantity         Category Sub-Category
# 0     102         7  Office Supplies      Binders
# 1      20         2        Furniture    Bookcases
# 2       7         6  Office Supplies      Storage
# 3       1         3  Office Supplies          Art
# 4      40         2       Technology  Accessories

# %%
df.groupby("Category").Sales.sum()
# Out:
# Category
# Furniture          2460
# Office Supplies    7970
# Technology         8588
# Name: Sales, dtype: int64

# %% [markdown]
# Dropping duplicates
# There are some duplicate rows in the combined data frame. Drop these rows and calculate the total sales value of the category Office Supplies.

# %%
df.drop_duplicates(inplace = True)

# %%
df.groupby("Category").Sales.sum()
# Out:
# Category
# Furniture          2460
# Office Supplies    6964
# Technology         7494
# Name: Sales, dtype: int64

# %% [markdown]
# Best Category-Sub category
#  Find the most profitable category and subcategory combination based on the net profit.
#
# Note: Use duplicates dropped data frame

# %%
df.groupby(["Category","Sub-Category"]).Profit.max()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       156
#                  Chairs           99
#                  Furnishings      34
# Office Supplies  Appliances      185
#                  Art             132
#                  Binders         102
#                  Envelopes        19
#                  Fasteners        10
#                  Labels            8
#                  Paper            15
#                  Storage         283
#                  Supplies         65
# Technology       Accessories     109
#                  Copiers           0
#                  Machines        168
#                  Phones          820
# Name: Profit, dtype: int64

# %% [markdown]
# Invalid order IDs
# How many invalid Order IDs are there in the data frame. Order ID is of the form AZ-2011-Y where Y represents a whole number. An Order ID is said to be valid only if Y consists of 7 digits. Find the number of invalid order IDs in the data frame.
#
# Note: Use duplicates dropped data frame

# %%
df["Order no"] = df["Order ID"].str.split("-")
df["Order no"] = df["Order no"].apply(lambda x: len(x[2]))

# %%
df["Order no"].value_counts()
# Out:
# Order no
# 7    54
# 6     7
# Name: count, dtype: int64

# %% [markdown]
# Occurence of furniture in top 25 sales
# Find the top 25 orders based on sales value and find the number of orders which belong to furniture category.
#
# Note: Use duplicates dropped data frame

# %%
sorted_df = df.sort_values(by = 'Sales', ascending = False)
sorted_df = sorted_df.head(25)

# %%
len(sorted_df[sorted_df.Category == "Furniture"])
# Out:
# 5

# %% [markdown]
# Multiple conditions
# Among the orders with sales>250 and profit>50, find the product name of the fourth highest order based on sales value.
#
# Note: Use duplicates dropped data frame

# %%
df_1 = df[(df["Sales"] > 250) & (df["Profit"] > 50)]
df_1.sort_values(by = "Sales", ascending = False)
# Out:
#            Order ID                         Product Name  Discount  Sales  \
# 30  AZ-2011-1410648         Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674                Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243     Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840     Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 18  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 39  AZ-2011-1536006      Logitech Keyboard, Programmable       0.0    666
# 33  AZ-2011-1445262          Apple Smart Phone, Cordless       0.0    636
# 31   AZ-2011-144325        Bush Stackable Bookrack, Pine       0.0    630
# 14  AZ-2011-1260928        Eldon File Cart, Single Width       0.1    576
# 12  AZ-2011-1253407       Safco Stackable Bookrack, Pine       0.1    541
# 48  AZ-2011-1672552      Binney & Smith Sketch Pad, Blue       0.0    510
# ...

# %%
df3=df.loc[(df['Sales']>250) & (df['Profit']>50)]
df3=df3.sort_values(by='Sales',ascending=False)

# %% [markdown]
# Column manipulation
# Remove the orders with negative profit by dropping the corresponding rows with negative Profit or no Profit. Now, among the entries with non-negative profit, find the product that makes the lowest profit per Quantity in the Technology category.
#
# Note: Use duplicates dropped data frame

# %%
# profit_df = df[df.Profit > 0]
# l = profit_df.sort_values(by = ["pro_Quan"], ascending = True)
# l[["Category", "pro_Quan"]]
l.apply(lambda x: x[x.Category == "Technology"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sk/6hdtmv_x63zfjkt1h_fv8sb00000gn/T/ipykernel_7634/1453994781.py in ?()
#       1 # profit_df = df[df.Profit > 0]
#       2 # l = profit_df.sort_values(by = ["pro_Quan"], ascending = True)
#       3 # l[["Category", "pro_Quan"]]
# ----> 4 l.apply(lambda x: x[x.Category == "Technology"])
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9419             result_type=result_type,
#    9420             args=args,
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py in ?(self)
#     674         # raw
#     675         elif self.raw:
#     676             return self.apply_raw()
#     677
# ...

# %%
l[l.Category == "Technology"]
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 4   AZ-2011-1967754      Logitech Numeric Keypad, USB       0.0     93
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
#
#     Profit  Quantity    Category Sub-Category  Order no    pro_Quan
# 39      66         9  Technology  Accessories         7    7.333333
# 2      109         7  Technology  Accessories         7   15.571429
# ...

# %%
profit_df["pro_Quan"] = profit_df.Profit / profit_df.Quantity
# Out:
# /var/folders/sk/6hdtmv_x63zfjkt1h_fv8sb00000gn/T/ipykernel_7634/1304906932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profit_df["pro_Quan"] = profit_df.Profit / profit_df.Quantity

# %%
profit_df
# Out:
#            Order ID                                       Product Name  \
# 0   AZ-2011-1902971                Wilson Jones Binding Machine, Clear
# 1   AZ-2011-1916360                      Dania 3-Shelf Cabinet, Mobile
# 2   AZ-2011-1916555                        Eldon Folders, Single Width
# 3   AZ-2011-1930058                        Sanford Markers, Easy-Erase
# 4   AZ-2011-1967754                       Logitech Numeric Keypad, USB
# 5   AZ-2011-1976919                               Boston Markers, Blue
# 6   AZ-2011-2001312                       Avery Binding Machine, Clear
# 7   AZ-2011-2002251          SanDisk Computer Printout Paper, 8.5 x 11
# 8    AZ-2011-201891       Cameo Clasp Envelope, with clear poly window
# 0   AZ-2011-1029887         Novimex Color Coded Labels, 5000 Label Set
# 1    AZ-2011-107716                     Deflect-O Door Stop, Erganomic
# 2   AZ-2011-1087704                      Belkin Flash Drive, Bluetooth
# ...

# %%
s = "I love Python"

# %%
s[2:6]
# Out:
# 'love'

# %%
s.split()[1]
# Out:
# 'love'

# %%
s[-11:-7]
# Out:
# 'love'
